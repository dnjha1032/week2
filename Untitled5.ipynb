# %%
#1. (a) Output is [30,10,20,50]
#   (b) Output is [30,10,50,40]

# %%
#2.ans-(a) ["Hello Drar","Hello Bye","Good Dear"."Good Bye"]

# %%
#3.ans-(b)

# %%
#4. ans-(a)

# %%
#5. ans- [4]
#        [2,3,4]
#  no such option is present

# %%
#6. ans-(b)

# %%
a=int(input("enter any number"))
prime=True
for i in range(2,a):
  if a%i==0:
    prime=False
if prime:
  print("given number is prime number")
else:
  print("given number is not prime number")

# %%
n=int(input("entre your number"))
def prime(n):
  for i in range(2,n):
    if n%i==0:
      return False
  return True    
print(prime(n))
# Out:
# entre your number67
# True
# Running cells with 'Python 3.10.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/New folder/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
def list():
  list=[1,2,3,4]
  b=len(list)
  s=0
  for i in range(b):
    s+=list[i]
print(s)
# Out:
# 10
# Running cells with 'Python 3.10.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/New folder/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
def convert(set):
  a=[1,5,8,5,6,5,8,2,1]
  return list(set(a))
print(convert(set))
# Out:
# Running cells with 'Python 3.10.4 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/New folder/python.exe" -m pip install ipykernel -U --user --force-reinstall'
